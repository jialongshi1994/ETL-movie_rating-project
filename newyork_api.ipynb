# %%
from config import api_key
import requests
import json
import pandas as pd
from pprint import pprint
import time

# %%
movie_names = []
from csv import reader
with open("movies_utf_8.csv", 'r') as reading_object:
    csv_reader = reader(reading_object)
    next(csv_reader)
    for i in csv_reader:
        movie_names.append(i[0])

# %%
movie_names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knight',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'Il buono, il brutto, il cattivo',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Fight Club',
#  'Forrest Gump',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Shichinin no samurai',
#  'Se7en',
#  'La vita ? bella',
#  'Cidade de Deus',
#  'The Silence of the Lambs',
#  "It's a Wonderful Life",
#  'Star Wars',
#  'Saving Private Ryan',
#  'Hamilton',
#  'Sen to Chihiro no kamikakushi',
#  'The Green Mile',
#  'Gisaengchung',
#  'Interstellar',
#  'L?on',
#  'The Usual Suspects',
#  'Seppuku',
#  'The Lion King',
#  'Back to the Future',
#  'The Pianist',
#  'Terminator 2: Judgment Day',
#  'American History X',
#  'Modern Times',
#  'Psycho',
#  'Gladiator',
#  'City Lights',
#  'The Departed',
#  'The Intouchables',
#  'Whiplash',
#  'The Prestige',
#  'Hotaru no haka',
#  'Once Upon a Time in the West',
#  'Casablanca',
#  'Nuovo Cinema Paradiso',
#  'Rear Window',
#  'Alien',
#  'Apocalypse Now',
#  'Memento',
#  'Raiders of the Lost Ark',
#  'The Great Dictator',
#  'Joker',
#  'The Lives of Others',
#  'Django Unchained',
#  'Paths of Glory',
#  'The Shining',
#  'WALL?E',
#  'Avengers: Infinity War',
#  'Sunset Blvd.',
#  'Mononoke-hime',
#  'Spider-Man: Into the Spider-Verse',
#  'Witness for the Prosecution',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Oldeuboi',
#  'The Dark Knight Rises',
#  'Once Upon a Time in America',
#  'Avengers: Endgame',
#  'Aliens',
#  'Kimi no na wa.',
#  'Coco',
#  'American Beauty',
#  'Braveheart',
#  '3 Idiots',
#  'Das Boot',
#  'Toy Story',
#  'Tengoku to jigoku',
#  'Amadeus',
#  'Taare Zameen Par',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Inglourious Basterds',
#  'Reservoir Dogs',
#  'Good Will Hunting',
#  'Capharna?m',
#  '2001: A Space Odyssey',
#  'Requiem for a Dream',
#  'Vertigo',
#  '1917',
#  'M - Eine Stadt sucht einen M?rder',
#  'Dangal',
#  'Eternal Sunshine of the Spotless Mind',
#  'Jagten',
#  'Citizen Kane',
#  'Full Metal Jacket',
#  'Ladri di biciclette',
#  'The Kid',
#  'A Clockwork Orange',
#  'North by Northwest',
#  'Snatch',
#  "Singin' in the Rain",
#  'Scarface',
#  'Taxi Driver',
#  'Am?lie',
#  'Lawrence of Arabia',
#  'Toy Story 3',
#  'Ikiru',
#  'The Sting',
#  'Metropolis',
#  'Jodaeiye Nader az Simin',
#  'Per qualche dollaro in pi?',
#  'Incendies',
#  'The Apartment',
#  'Double Indemnity',
#  'To Kill a Mockingbird',
#  'Idi i smotri',
#  'Indiana Jones and the Last Crusade',
#  'Up',
#  'L.A. Confidential',
#  'Heat',
#  'Anand',
#  'Monty Python and the Holy Grail',
#  'Die Hard',
#  'Rash?mon',
#  'Y?jinb?',
#  'Batman Begins',
#  'Green Book',
#  'Der Untergang',
#  'Bacheha-Ye aseman',
#  'Unforgiven',
#  'Some Like It Hot',
#  'Ran',
#  'Hauru no ugoku shiro',
#  'The Great Escape',
#  'All About Eve',
#  'A Beautiful Mind',
#  'Casino',
#  "Pan's Labyrinth",
#  'The Wolf of Wall Street',
#  'El secreto de sus ojos',
#  'Lock, Stock and Two Smoking Barrels',
#  'Tonari no Totoro',
#  'Raging Bull',
#  'There Will Be Blood',
#  'Judgment at Nuremberg',
#  'The Treasure of the Sierra Madre',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Babam ve Oglum',
#  'Dial M for Murder',
#  'The Gold Rush',
#  'Chinatown',
#  'V for Vendetta',
#  'No Country for Old Men',
#  'Shutter Island',
#  'Det sjunde inseglet',
#  'Inside Out',
#  'Warrior',
#  'The Elephant Man',
#  'Trainspotting',
#  'The Sixth Sense',
#  'The Thing',
#  'Jurassic Park',
#  'Gone with the Wind',
#  'Smultronst?llet',
#  'Blade Runner',
#  'Finding Nemo',
#  'The Truman Show',
#  'Room',
#  'The Bridge on the River Kwai',
#  'Stalker',
#  'Kill Bill: Vol. 1',
#  'Fargo',
#  'The Third Man',
#  'On the Waterfront',
#  'T?ky? monogatari',
#  'Gran Torino',
#  'Salinui chueok',
#  'The Deer Hunter',
#  'Relatos salvajes',
#  'Andhadhun',
#  'Klaus',
#  'In the Name of the Father',
#  'Mary and Max',
#  'Gone Girl',
#  'The Big Lebowski',
#  'Hacksaw Ridge',
#  'The Grand Budapest Hotel',
#  'Eskiya',
#  'Before Sunrise',
#  'To Be or Not to Be',
#  'Catch Me If You Can',
#  'Persona',
#  'Ford v Ferrari: The IMAX 2D Experience',
#  'The General',
#  'How to Train Your Dragon',
#  'Prisoners',
#  'Sherlock Jr.',
#  'Mr. Smith Goes to Washington',
#  '12 Years a Slave',
#  'Barry Lyndon',
#  'Mad Max: Fury Road',
#  'Stand by Me',
#  'Network',
#  'Cool Hand Luke',
#  'Million Dollar Baby',
#  'Into the Wild',
#  "Hachi: A Dog's Tale",
#  'Ben-Hur',
#  'Le salaire de la peur',
#  'Dead Poets Society',
#  'Platoon',
#  'Life of Brian',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Logan',
#  'Rush',
#  'Du rififi chez les hommes',
#  "La passion de Jeanne d'Arc",
#  'Ah-ga-ssi',
#  'Andrei Rublev',
#  'Les quatre cents coups',
#  'Hotel Rwanda',
#  'Spotlight',
#  'Amores perros',
#  'Rang De Basanti',
#  'Kaze no tani no Naushika',
#  'Rocky',
#  'La haine',
#  'Gangs of Wasseypur',
#  'Monsters, Inc.',
#  'Rebecca',
#  'Portrait de la jeune fille en feu',
#  'The Circus',
#  'Before Sunset',
#  'It Happened One Night',
#  'Fa yeung nin wah',
#  'Paris, Texas',
#  'Drishyam',
#  'Contratiempo',
#  'The Help',
#  'The Princess Bride',
#  'The Terminator',
#  'La battaglia di Algeri',
#  'Kumonosu-j?',
#  'Swades: We, the People',
#  'Munna Bhai M.B.B.S.',
#  'Shin seiki Evangelion Gekij?-ban: Air/Magokoro wo, kimi ni']

# %%
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
response_list = []
alternate_list = []
for x in movie_names:
    base_url = url + "query=" + str(x) + "&api-key=" + api_key
    response = requests.get(base_url).json()
    response_list.append(response)
    if response['results'] != []:
        alternate_list.append(response['results'][int(0)])
    time.sleep(6)

# %%
no_result_count = 0
for x in response_list:
    if x['results'] == []:
        no_result_count += 1
print(no_result_count)
# Out:
# 65

# %%
# alternate_list

# %%
with open('alternate.json', 'w', encoding='UTF-8') as hey:
    json.dump(alternate_list, hey, ensure_ascii=False, indent=4)

# %%
thedf = pd.read_json('alternate.json')
thedf # 185 rows. missing 65 results from api.
# Out:
#                                display_title mpaa_rating  critics_pick  \
# 0                   The Shawshank Redemption           R             0
# 1    Square Grouper: The Godfathers of Ganja           R             0
# 2                    The Godfather, Part III           R             1
# 3                      The Dark Knight Rises       PG-13             1
# 4                               12 Angry Men   Not Rated             1
# ..                                       ...         ...           ...
# 180                    It Happened One Night   Not Rated             1
# 181                             Paris, Texas           R             0
# 182                                 The Help       PG-13             0
# 183                       The Princess Bride          PG             0
# 184                           The Terminator           R             0
#
#              byline                                           headline  \
# 0      Janet Maslin  Prison Tale by Stephen King Told Gently, Belie...
# 1      RACHEL SALTZ                      Adventures in the Drug Trades
# 2      Janet Maslin                         GODFATHER PART III (MOVIE)
# 3    MANOHLA DARGIS        A Rejected Superhero Ends Up at Ground Zero
# 4       A.H. WEILER                                       12 Angry Men
# ..              ...                                                ...
# 180  MORDAUNT HALL.                              It Happened One Night
# 181   Vincent Canby                               PARIS, TEXAS (MOVIE)
# 182  MANOHLA DARGIS                     ‘The Maids’ Now Have Their Say
# 183    Janet Maslin                        Princess Bride, The (Movie)
# 184    Janet Maslin                            TERMINATOR, THE (MOVIE)
#
#                                          summary_short publication_date  \
# 0                                                 None       1994-09-23
# 1    “Square Grouper” is a documentary about pot sm...       2011-04-14
# 2    Mafia heir trapped by legacy of past. Coppola'...       1990-12-25
# 3    Christopher Nolan’s “Dark Knight Rises” wraps ...       2012-07-18
# 4            Male jury and stubborn holdout. Piercing.       1957-04-15
# ..                                                 ...              ...
# 180  Heiress and newspaperman on Miami bus headed n...       1934-02-23
# 181  Man reunites with family, via Sam Shepard. Goo...       1984-10-14
# 182  “The Help,” Tate Taylor’s movie set in civil-r...       2011-08-09
# 183  Torn between devious prince and true-love pira...       1987-09-25
# 184   Ruthless cyborg from future. Fast, vivid sci-fi.       1984-10-26
#
#     opening_date         date_updated  \
# 0     1994-10-14  2017-11-02 04:17:47
# 1     2011-04-15  2017-11-02 04:18:13
# 2     1990-12-25  2017-11-02 04:17:42
# 3     2012-07-20  2017-11-02 04:18:15
# 4     1957-04-01  2017-11-02 04:17:18
# ..           ...                  ...
# 180   1934-02-23  2017-11-02 04:16:54
# 181         None  2017-11-02 04:16:08
# 182   2011-08-10  2017-11-02 04:18:13
# 183   1987-10-09  2017-11-02 04:17:38
# 184   1984-10-26  2017-11-02 04:17:33
#
#                                                   link multimedia
# 0    {'type': 'article', 'url': 'http://www.nytimes...       None
# 1    {'type': 'article', 'url': 'http://www.nytimes...       None
# 2    {'type': 'article', 'url': 'http://www.nytimes...       None
# 3    {'type': 'article', 'url': 'http://www.nytimes...       None
# 4    {'type': 'article', 'url': 'http://www.nytimes...       None
# ..                                                 ...        ...
# 180  {'type': 'article', 'url': 'http://www.nytimes...       None
# 181  {'type': 'article', 'url': 'http://www.nytimes...       None
# 182  {'type': 'article', 'url': 'http://www.nytimes...       None
# 183  {'type': 'article', 'url': 'http://www.nytimes...       None
# 184  {'type': 'article', 'url': 'http://www.nytimes...       None
#
# [185 rows x 11 columns]
