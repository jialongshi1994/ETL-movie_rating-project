# %%
from config import api_key
import requests
import json
import pandas as pd
from pprint import pprint

# %%
movie_names = []
from csv import reader
with open("movies_utf_8.csv", 'r') as reading_object:
    csv_reader = reader(reading_object)
    next(csv_reader)
    for i in csv_reader:
        movie_names.append(i[0])

# %%
movie_names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knight',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'Il buono, il brutto, il cattivo',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Fight Club',
#  'Forrest Gump',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Shichinin no samurai',
#  'Se7en',
#  'La vita ? bella',
#  'Cidade de Deus',
#  'The Silence of the Lambs',
#  "It's a Wonderful Life",
#  'Star Wars',
#  'Saving Private Ryan',
#  'Hamilton',
#  'Sen to Chihiro no kamikakushi',
#  'The Green Mile',
#  'Gisaengchung',
#  'Interstellar',
#  'L?on',
#  'The Usual Suspects',
#  'Seppuku',
#  'The Lion King',
#  'Back to the Future',
#  'The Pianist',
#  'Terminator 2: Judgment Day',
#  'American History X',
#  'Modern Times',
#  'Psycho',
#  'Gladiator',
#  'City Lights',
#  'The Departed',
#  'The Intouchables',
#  'Whiplash',
#  'The Prestige',
#  'Hotaru no haka',
#  'Once Upon a Time in the West',
#  'Casablanca',
#  'Nuovo Cinema Paradiso',
#  'Rear Window',
#  'Alien',
#  'Apocalypse Now',
#  'Memento',
#  'Raiders of the Lost Ark',
#  'The Great Dictator',
#  'Joker',
#  'The Lives of Others',
#  'Django Unchained',
#  'Paths of Glory',
#  'The Shining',
#  'WALL?E',
#  'Avengers: Infinity War',
#  'Sunset Blvd.',
#  'Mononoke-hime',
#  'Spider-Man: Into the Spider-Verse',
#  'Witness for the Prosecution',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Oldeuboi',
#  'The Dark Knight Rises',
#  'Once Upon a Time in America',
#  'Avengers: Endgame',
#  'Aliens',
#  'Kimi no na wa.',
#  'Coco',
#  'American Beauty',
#  'Braveheart',
#  '3 Idiots',
#  'Das Boot',
#  'Toy Story',
#  'Tengoku to jigoku',
#  'Amadeus',
#  'Taare Zameen Par',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Inglourious Basterds',
#  'Reservoir Dogs',
#  'Good Will Hunting',
#  'Capharna?m',
#  '2001: A Space Odyssey',
#  'Requiem for a Dream',
#  'Vertigo',
#  '1917',
#  'M - Eine Stadt sucht einen M?rder',
#  'Dangal',
#  'Eternal Sunshine of the Spotless Mind',
#  'Jagten',
#  'Citizen Kane',
#  'Full Metal Jacket',
#  'Ladri di biciclette',
#  'The Kid',
#  'A Clockwork Orange',
#  'North by Northwest',
#  'Snatch',
#  "Singin' in the Rain",
#  'Scarface',
#  'Taxi Driver',
#  'Am?lie',
#  'Lawrence of Arabia',
#  'Toy Story 3',
#  'Ikiru',
#  'The Sting',
#  'Metropolis',
#  'Jodaeiye Nader az Simin',
#  'Per qualche dollaro in pi?',
#  'Incendies',
#  'The Apartment',
#  'Double Indemnity',
#  'To Kill a Mockingbird',
#  'Idi i smotri',
#  'Indiana Jones and the Last Crusade',
#  'Up',
#  'L.A. Confidential',
#  'Heat',
#  'Anand',
#  'Monty Python and the Holy Grail',
#  'Die Hard',
#  'Rash?mon',
#  'Y?jinb?',
#  'Batman Begins',
#  'Green Book',
#  'Der Untergang',
#  'Bacheha-Ye aseman',
#  'Unforgiven',
#  'Some Like It Hot',
#  'Ran',
#  'Hauru no ugoku shiro',
#  'The Great Escape',
#  'All About Eve',
#  'A Beautiful Mind',
#  'Casino',
#  "Pan's Labyrinth",
#  'The Wolf of Wall Street',
#  'El secreto de sus ojos',
#  'Lock, Stock and Two Smoking Barrels',
#  'Tonari no Totoro',
#  'Raging Bull',
#  'There Will Be Blood',
#  'Judgment at Nuremberg',
#  'The Treasure of the Sierra Madre',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Babam ve Oglum',
#  'Dial M for Murder',
#  'The Gold Rush',
#  'Chinatown',
#  'V for Vendetta',
#  'No Country for Old Men',
#  'Shutter Island',
#  'Det sjunde inseglet',
#  'Inside Out',
#  'Warrior',
#  'The Elephant Man',
#  'Trainspotting',
#  'The Sixth Sense',
#  'The Thing',
#  'Jurassic Park',
#  'Gone with the Wind',
#  'Smultronst?llet',
#  'Blade Runner',
#  'Finding Nemo',
#  'The Truman Show',
#  'Room',
#  'The Bridge on the River Kwai',
#  'Stalker',
#  'Kill Bill: Vol. 1',
#  'Fargo',
#  'The Third Man',
#  'On the Waterfront',
#  'T?ky? monogatari',
#  'Gran Torino',
#  'Salinui chueok',
#  'The Deer Hunter',
#  'Relatos salvajes',
#  'Andhadhun',
#  'Klaus',
#  'In the Name of the Father',
#  'Mary and Max',
#  'Gone Girl',
#  'The Big Lebowski',
#  'Hacksaw Ridge',
#  'The Grand Budapest Hotel',
#  'Eskiya',
#  'Before Sunrise',
#  'To Be or Not to Be',
#  'Catch Me If You Can',
#  'Persona',
#  'Ford v Ferrari: The IMAX 2D Experience',
#  'The General',
#  'How to Train Your Dragon',
#  'Prisoners',
#  'Sherlock Jr.',
#  'Mr. Smith Goes to Washington',
#  '12 Years a Slave',
#  'Barry Lyndon',
#  'Mad Max: Fury Road',
#  'Stand by Me',
#  'Network',
#  'Cool Hand Luke',
#  'Million Dollar Baby',
#  'Into the Wild',
#  "Hachi: A Dog's Tale",
#  'Ben-Hur',
#  'Le salaire de la peur',
#  'Dead Poets Society',
#  'Platoon',
#  'Life of Brian',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Logan',
#  'Rush',
#  'Du rififi chez les hommes',
#  "La passion de Jeanne d'Arc",
#  'Ah-ga-ssi',
#  'Andrei Rublev',
#  'Les quatre cents coups',
#  'Hotel Rwanda',
#  'Spotlight',
#  'Amores perros',
#  'Rang De Basanti',
#  'Kaze no tani no Naushika',
#  'Rocky',
#  'La haine',
#  'Gangs of Wasseypur',
#  'Monsters, Inc.',
#  'Rebecca',
#  'Portrait de la jeune fille en feu',
#  'The Circus',
#  'Before Sunset',
#  'It Happened One Night',
#  'Fa yeung nin wah',
#  'Paris, Texas',
#  'Drishyam',
#  'Contratiempo',
#  'The Help',
#  'The Princess Bride',
#  'The Terminator',
#  'La battaglia di Algeri',
#  'Kumonosu-j?',
#  'Swades: We, the People',
#  'Munna Bhai M.B.B.S.',
#  'Shin seiki Evangelion Gekij?-ban: Air/Magokoro wo, kimi ni']

# %%
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
response_list = []
alternate_list = []
for x in movie_names[:10]:
    base_url = url + "query=" + str(x) + "&api-key=" + api_key
    response = requests.get(base_url).json()
    response_list.append(response)
    if response['results'] != []:
        alternate_list.append(response['results'][int(0)])

# %%
alternate_list
# Out:
# [{'display_title': 'The Shawshank Redemption',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'Prison Tale by Stephen King Told Gently, Believe It or Not',
#   'summary_short': None,
#   'publication_date': '1994-09-23',
#   'opening_date': '1994-10-14',
#   'date_updated': '2017-11-02 04:17:47',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1994/09/23/movies/film-review-prison-tale-by-stephen-king-told-gently-believe-it-or-not.html',
#    'suggested_link_text': 'Read the New York Times Review of The Shawshank Redemption'},
#   'multimedia': None},
#  {'display_title': 'Square Grouper: The Godfathers of Ganja',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'RACHEL SALTZ',
#   'headline': 'Adventures in the Drug Trades',
#   'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.',
#   'publication_date': '2011-04-14',
#   'opening_date': '2011-04-15',
#   'date_updated': '2017-11-02 04:18:13',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2011/04/15/movies/square-grouper-movie-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Square Grouper: The Godfathers of Ganja'},
#   'multimedia': None},
#  {'display_title': 'The Godfather, Part III',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'GODFATHER PART III (MOVIE)',
#   'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving.",
#   'publication_date': '1990-12-25',
#   'opening_date': '1990-12-25',
#   'date_updated': '2017-11-02 04:17:42',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1990/12/25/movies/review-film-the-corleones-try-to-go-straight-in-the-godfather-part-iii.html',
#    'suggested_link_text': 'Read the New York Times Review of The Godfather, Part III'},
#   'multimedia': None},
#  {'display_title': 'The Dark Knight Rises',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'MANOHLA DARGIS',
#   'headline': 'A Rejected Superhero Ends Up at Ground Zero',
#   'summary_short': 'Christopher Nolan’s “Dark Knight Rises” wraps up his post-Sept. 11 epic of ambivalent good vs. multidimensional evil with a burst of light.',
#   'publication_date': '2012-07-18',
#   'opening_date': '2012-07-20',
#   'date_updated': '2017-11-02 04:18:15',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2012/07/20/movies/the-dark-knight-rises-with-christian-bale.html',
#    'suggested_link_text': 'Read the New York Times Review of The Dark Knight Rises'},
#   'multimedia': None},
#  {'display_title': '12 Angry Men',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 1,
#   'byline': 'A.H. WEILER',
#   'headline': '12 Angry Men',
#   'summary_short': 'Male jury and stubborn holdout. Piercing.',
#   'publication_date': '1957-04-15',
#   'opening_date': '1957-04-01',
#   'date_updated': '2017-11-02 04:17:18',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1957/04/15/archives/screen-12-angry-men-jury-room-drama-has-debut-at-capitol.html',
#    'suggested_link_text': 'Read the New York Times Review of 12 Angry Men'},
#   'multimedia': None},
#  {'display_title': "Schindler's List",
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': "SCHINDLER'S LIST (MOVIE)",
#   'summary_short': "Austrian industrialist who saved Jews from Nazi camps. Spielberg's masterly Oscar-winning drama.",
#   'publication_date': '1993-12-15',
#   'opening_date': '1994-02-04',
#   'date_updated': '2017-11-02 04:17:46',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1993/12/15/movies/review-film-schindler-s-list-imagining-the-holocaust-to-remember-it.html',
#    'suggested_link_text': "Read the New York Times Review of Schindler's List"},
#   'multimedia': None},
#  {'display_title': 'The Lord of the Rings: The Return of the King',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Triumph Tinged With Regret in Middle Earth',
#   'summary_short': "After the galloping intelligence displayed in the first two parts of &quot;The Lord of the Rings&quot; series, your fear may be that Peter Jackson would become cautious and unimaginative with the last episode of his trilogy. But Mr. Jackson crushes any such fear. His &quot;King&quot; is a meticulous and prodigious vision made by a director who was not hamstrung by heavy use of computer special-effects imagery. The final installment  follows the hobbit Frodo (Elijah Wood), increasingly fevered as the ring exercises its power over him, on the last leg of his perilous journey to Mordor to destroy the sinister object.  The wizard Gandalf (Ian McKellen), in a voice sodden with mellow sadness, believes that Frodo is on a suicide mission: &quot;There never was much hope. Just a false hope.&quot; Mr. Jackson takes his time with the story, but he's not sloughing off here. Rather he is building toward a more than solid conclusion. The grandiloquence that sustained the second installment, &quot;The Two Towers,&quot; with its pounding and operatic martial fury — a movie that actually created a state of siege and left audiences hanging —  can be found here. By its end, &quot;King&quot; glides to the gentle bonhomie that opened the &quot;Ring&quot; movies, but its epilogue is tinged with regret: &quot;You can't go back. Some wounds don't heal.&quot; It's an epic about the price of triumph, a subversive victory itself in a large-scale pop-action film. — Elvis Mitchell",
#   'publication_date': '2003-12-16',
#   'opening_date': '2003-12-17',
#   'date_updated': '2017-11-02 04:18:03',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2003/12/16/movies/film-review-triumph-tinged-with-regret-in-middle-earth.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lord of the Rings: The Return of the King'},
#   'multimedia': None},
#  {'display_title': 'Pulp Fiction',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'PULP FICTION (MOVIE)',
#   'summary_short': "Director Quentin Tarantino's linked vignettes about petty hoodlums and their ilk. Shocking, funny and blazingly original.",
#   'publication_date': '1994-09-23',
#   'opening_date': '1994-10-14',
#   'date_updated': '2017-11-02 04:17:47',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1994/09/23/movies/film-festival-review-pulp-fiction-quentin-tarantino-s-wild-ride-life-s-dangerous.html',
#    'suggested_link_text': 'Read the New York Times Review of Pulp Fiction'},
#   'multimedia': None},
#  {'display_title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Lord of the Rings, the (Movies) ',
#   'summary_short': "During a birthday celebration, the hobbit Frodo (Elijah Wood) receives a ring that places him in the center of a struggle for the future of the world. The ring, which contains an evil wizard's &quot;will to dominate all life,&quot; must be destroyed in the fire Pits of Mordor, where it was created. &quot;Fellowship&quot; then slips into a series of chases and pitched battles, each with a bit more at stake because the ring's power to tempt those who come in contact with it becomes a bigger factor. There are two groups probably sharing the same dread about this film adaptation of J. R. R. Tolkien's ornate and busy work: its most loving adherents and those who have spent their lives avoiding the books. But neither side is likely to be disappointed by Peter Jackson's altogether heroic job in tackling perhaps the most intimidating nerd/academic fantasy classic ever. – Elvis Mitchell",
#   'publication_date': '2001-12-19',
#   'opening_date': '2001-12-19',
#   'date_updated': '2017-11-02 04:18:00',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2001/12/19/movies/film-review-hit-the-road-middle-earth-gang.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lord of the Rings: The Fellowship of the Ring'},
#   'multimedia': None}]

# %%
with open('alternate.json', 'w', encoding='UTF-8') as hey:
    json.dump(alternate_list, hey, ensure_ascii=False, indent=4)

# %%
thedf = pd.read_json('alternate.json')
thedf.head()
# Out:
#                              display_title mpaa_rating  critics_pick  \
# 0                 The Shawshank Redemption           R             0
# 1  Square Grouper: The Godfathers of Ganja           R             0
# 2                  The Godfather, Part III           R             1
# 3                    The Dark Knight Rises       PG-13             1
# 4                             12 Angry Men   Not Rated             1
#
#            byline                                           headline  \
# 0    Janet Maslin  Prison Tale by Stephen King Told Gently, Belie...
# 1    RACHEL SALTZ                      Adventures in the Drug Trades
# 2    Janet Maslin                         GODFATHER PART III (MOVIE)
# 3  MANOHLA DARGIS        A Rejected Superhero Ends Up at Ground Zero
# 4     A.H. WEILER                                       12 Angry Men
#
#                                        summary_short publication_date  \
# 0                                               None       1994-09-23
# 1  “Square Grouper” is a documentary about pot sm...       2011-04-14
# 2  Mafia heir trapped by legacy of past. Coppola'...       1990-12-25
# 3  Christopher Nolan’s “Dark Knight Rises” wraps ...       2012-07-18
# 4          Male jury and stubborn holdout. Piercing.       1957-04-15
#
#   opening_date         date_updated  \
# 0   1994-10-14  2017-11-02 04:17:47
# 1   2011-04-15  2017-11-02 04:18:13
# 2   1990-12-25  2017-11-02 04:17:42
# 3   2012-07-20  2017-11-02 04:18:15
# 4   1957-04-01  2017-11-02 04:17:18
#
#                                                 link  multimedia
# 0  {'type': 'article', 'url': 'http://www.nytimes...         NaN
# 1  {'type': 'article', 'url': 'http://www.nytimes...         NaN
# 2  {'type': 'article', 'url': 'http://www.nytimes...         NaN
# 3  {'type': 'article', 'url': 'http://www.nytimes...         NaN
# 4  {'type': 'article', 'url': 'http://www.nytimes...         NaN
