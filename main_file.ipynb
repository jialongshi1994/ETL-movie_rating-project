# %%
from config import api_key
import requests
import json
import pandas as pd
from pprint import pprint
import time

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.imdb.com/chart/top/?ref_=nv_mv_250"

# %%
page= requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.text, "html.parser")

# %%
raw_html = soup.find("tbody", {"class": "lister-list"}).findAll("tr")

# %%
movie_list = []
for html in raw_html:
    title = html.find("td", {"class": "titleColumn"}).find("a").get_text()
    year = html.find("td", {"class": "titleColumn"}).find("span").getText()[1:5]
    rating= html.find("td", {"class": "ratingColumn imdbRating"}).find("strong").get_text()
    rating= float(rating)
        
    raw_list= [title, year, rating]
    movie_list.append(raw_list)

# %%
import pandas as pd

# %%
thedf = pd.DataFrame(movie_list)

# %%
imdb_df = thedf.rename(columns={0:"movie_name", 1:"year", 2:"rating"})

# %%
movie_name = imdb_df['movie_name']

# %%
imdb_df.set_index('movie_name', inplace=True)

# %%
imdb_df
# Out:
#                                                     year  rating
# movie_name
# The Shawshank Redemption                            1994     9.2
# The Godfather                                       1972     9.1
# The Godfather: Part II                              1974     9.0
# The Dark Knight                                     2008     9.0
# 12 Angry Men                                        1957     8.9
# ...                                                  ...     ...
# La battaglia di Algeri                              1966     8.0
# Swades: We, the People                              2004     8.0
# Hera Pheri                                          2000     8.0
# Kumonosu-jô                                         1957     8.0
# Shin seiki Evangelion Gekijô-ban: Air/Magokoro ...  1997     8.0
#
# [250 rows x 2 columns]

# %%
print(movie_name)
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           12 Angry Men
#                              ...
# 245                               La battaglia di Algeri
# 246                               Swades: We, the People
# 247                                           Hera Pheri
# 248                                          Kumonosu-jô
# 249    Shin seiki Evangelion Gekijô-ban: Air/Magokoro...
# Name: movie_name, Length: 250, dtype: object

# %%
# NYT api

# %%
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
response_list = []
alternate_list = []
movies_nyt = []
movies_wedidntget = []
for x in movie_name:
    try:
        base_url = url + "query=" + str(x) + "&api-key=" + api_key
        response = requests.get(base_url).json()
        response_list.append(response)
        if response['results'] != []:
            alternate_list.append(response['results'][int(0)])
            movies_nyt.append(x)
            time.sleep(6)
    except:
        movies_wedidntget.append(x)
        next
        time.sleep(6)

# %%
alternate_list
# Out:
# [{'display_title': 'The Shawshank Redemption',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'Prison Tale by Stephen King Told Gently, Believe It or Not',
#   'summary_short': None,
#   'publication_date': '1994-09-23',
#   'opening_date': '1994-10-14',
#   'date_updated': '2017-11-02 04:17:47',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1994/09/23/movies/film-review-prison-tale-by-stephen-king-told-gently-believe-it-or-not.html',
#    'suggested_link_text': 'Read the New York Times Review of The Shawshank Redemption'},
#   'multimedia': None},
#  {'display_title': 'Square Grouper: The Godfathers of Ganja',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'RACHEL SALTZ',
#   'headline': 'Adventures in the Drug Trades',
#   'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.',
#   'publication_date': '2011-04-14',
#   'opening_date': '2011-04-15',
#   'date_updated': '2017-11-02 04:18:13',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2011/04/15/movies/square-grouper-movie-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Square Grouper: The Godfathers of Ganja'},
#   'multimedia': None},
#  {'display_title': 'The Godfather, Part III',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'GODFATHER PART III (MOVIE)',
#   'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving.",
#   'publication_date': '1990-12-25',
#   'opening_date': '1990-12-25',
#   'date_updated': '2017-11-02 04:17:42',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1990/12/25/movies/review-film-the-corleones-try-to-go-straight-in-the-godfather-part-iii.html',
#    'suggested_link_text': 'Read the New York Times Review of The Godfather, Part III'},
#   'multimedia': None},
#  {'display_title': 'The Dark Knight Rises',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'MANOHLA DARGIS',
#   'headline': 'A Rejected Superhero Ends Up at Ground Zero',
#   'summary_short': 'Christopher Nolan’s “Dark Knight Rises” wraps up his post-Sept. 11 epic of ambivalent good vs. multidimensional evil with a burst of light.',
#   'publication_date': '2012-07-18',
#   'opening_date': '2012-07-20',
#   'date_updated': '2017-11-02 04:18:15',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2012/07/20/movies/the-dark-knight-rises-with-christian-bale.html',
#    'suggested_link_text': 'Read the New York Times Review of The Dark Knight Rises'},
#   'multimedia': None},
#  {'display_title': '12 Angry Men',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 1,
#   'byline': 'A.H. WEILER',
#   'headline': '12 Angry Men',
#   'summary_short': 'Male jury and stubborn holdout. Piercing.',
#   'publication_date': '1957-04-15',
#   'opening_date': '1957-04-01',
#   'date_updated': '2017-11-02 04:17:18',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1957/04/15/archives/screen-12-angry-men-jury-room-drama-has-debut-at-capitol.html',
#    'suggested_link_text': 'Read the New York Times Review of 12 Angry Men'},
#   'multimedia': None},
#  {'display_title': "Schindler's List",
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': "SCHINDLER'S LIST (MOVIE)",
#   'summary_short': "Austrian industrialist who saved Jews from Nazi camps. Spielberg's masterly Oscar-winning drama.",
#   'publication_date': '1993-12-15',
#   'opening_date': '1994-02-04',
#   'date_updated': '2017-11-02 04:17:46',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1993/12/15/movies/review-film-schindler-s-list-imagining-the-holocaust-to-remember-it.html',
#    'suggested_link_text': "Read the New York Times Review of Schindler's List"},
#   'multimedia': None},
#  {'display_title': 'The Lord of the Rings: The Return of the King',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Triumph Tinged With Regret in Middle Earth',
#   'summary_short': "After the galloping intelligence displayed in the first two parts of &quot;The Lord of the Rings&quot; series, your fear may be that Peter Jackson would become cautious and unimaginative with the last episode of his trilogy. But Mr. Jackson crushes any such fear. His &quot;King&quot; is a meticulous and prodigious vision made by a director who was not hamstrung by heavy use of computer special-effects imagery. The final installment  follows the hobbit Frodo (Elijah Wood), increasingly fevered as the ring exercises its power over him, on the last leg of his perilous journey to Mordor to destroy the sinister object.  The wizard Gandalf (Ian McKellen), in a voice sodden with mellow sadness, believes that Frodo is on a suicide mission: &quot;There never was much hope. Just a false hope.&quot; Mr. Jackson takes his time with the story, but he's not sloughing off here. Rather he is building toward a more than solid conclusion. The grandiloquence that sustained the second installment, &quot;The Two Towers,&quot; with its pounding and operatic martial fury — a movie that actually created a state of siege and left audiences hanging —  can be found here. By its end, &quot;King&quot; glides to the gentle bonhomie that opened the &quot;Ring&quot; movies, but its epilogue is tinged with regret: &quot;You can't go back. Some wounds don't heal.&quot; It's an epic about the price of triumph, a subversive victory itself in a large-scale pop-action film. — Elvis Mitchell",
#   'publication_date': '2003-12-16',
#   'opening_date': '2003-12-17',
#   'date_updated': '2017-11-02 04:18:03',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2003/12/16/movies/film-review-triumph-tinged-with-regret-in-middle-earth.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lord of the Rings: The Return of the King'},
#   'multimedia': None},
#  {'display_title': 'Pulp Fiction',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'PULP FICTION (MOVIE)',
#   'summary_short': "Director Quentin Tarantino's linked vignettes about petty hoodlums and their ilk. Shocking, funny and blazingly original.",
#   'publication_date': '1994-09-23',
#   'opening_date': '1994-10-14',
#   'date_updated': '2017-11-02 04:17:47',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1994/09/23/movies/film-festival-review-pulp-fiction-quentin-tarantino-s-wild-ride-life-s-dangerous.html',
#    'suggested_link_text': 'Read the New York Times Review of Pulp Fiction'},
#   'multimedia': None},
#  {'display_title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Lord of the Rings, the (Movies) ',
#   'summary_short': "During a birthday celebration, the hobbit Frodo (Elijah Wood) receives a ring that places him in the center of a struggle for the future of the world. The ring, which contains an evil wizard's &quot;will to dominate all life,&quot; must be destroyed in the fire Pits of Mordor, where it was created. &quot;Fellowship&quot; then slips into a series of chases and pitched battles, each with a bit more at stake because the ring's power to tempt those who come in contact with it becomes a bigger factor. There are two groups probably sharing the same dread about this film adaptation of J. R. R. Tolkien's ornate and busy work: its most loving adherents and those who have spent their lives avoiding the books. But neither side is likely to be disappointed by Peter Jackson's altogether heroic job in tackling perhaps the most intimidating nerd/academic fantasy classic ever. – Elvis Mitchell",
#   'publication_date': '2001-12-19',
#   'opening_date': '2001-12-19',
#   'date_updated': '2017-11-02 04:18:00',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2001/12/19/movies/film-review-hit-the-road-middle-earth-gang.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lord of the Rings: The Fellowship of the Ring'},
#   'multimedia': None},
#  {'display_title': 'Fight Club',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'Fight Club (Movie)  ',
#   'summary_short': "The sardonic, testosterone-fueled science fiction of this grunge parable means to hit raw nerves. Making a tougher but less stomach-turning film than his earlier &quot;Seven,&quot; David Fincher taps into the nexus of computer-age malevolent fantasy and attempts to psychoanalyze an entire culture in ways that aren't entirely clear until the film's whammy of a denouement arrives. A reckless but fascinating attempt, expertly acted, to make sense of contemporary frustrations. — Janet Maslin",
#   'publication_date': '1999-10-15',
#   'opening_date': '1999-10-15',
#   'date_updated': '2017-11-02 04:17:57',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1999/10/15/movies/film-review-such-a-very-long-way-from-duvets-to-danger.html',
#    'suggested_link_text': 'Read the New York Times Review of Fight Club'},
#   'multimedia': None},
#  {'display_title': 'Forrest Gump',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'FORREST GUMP (MOVIE)',
#   'summary_short': "Slow-witted innocent caught up in 20th century's great events. Good special effects, haunting Hanks.",
#   'publication_date': '1994-07-06',
#   'opening_date': '1994-07-06',
#   'date_updated': '2017-11-02 04:17:47',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1994/07/06/movies/film-review-tom-hanks-as-an-interloper-in-history.html',
#    'suggested_link_text': 'Read the New York Times Review of Forrest Gump'},
#   'multimedia': None},
#  {'display_title': 'Inception',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'A. O. SCOTT',
#   'headline': 'This Time the Dream’s on Me',
#   'summary_short': 'In Christopher Nolan’s “Inception” a specialist in corporate mental espionage and his co-workers penetrate the minds of their slumbering targets.',
#   'publication_date': '2010-07-15',
#   'opening_date': '2010-07-16',
#   'date_updated': '2017-11-02 04:18:11',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2010/07/16/movies/16inception.html',
#    'suggested_link_text': 'Read the New York Times Review of Inception'},
#   'multimedia': None},
#  {'display_title': 'The Lord of the Rings: The Two Towers',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Lord of the Rings, The: The Two Towers (Movie)',
#   'summary_short': "Peter Jackson's scrupulous devotion to the spirit of J.R.R. Tolkien's &quot;Lord of the Rings&quot; trilogy manifests itself in a gripping, intense fashion in this second of the film adaptations. It may be the first sequel that does not bother to give a reprise of the major plot elements of its predecessor immediately; the plan is simply to drop us right into the action. This stratagem creates a few moments of apprehension, the same disconcerted quality that the hobbits Frodo (Elijah Wood) and Sam (Sean Astin) are experiencing on their journey. Their mission began in &quot;The Fellowship of the Ring&quot; when Frodo was entrusted with the ring that gives its bearer enormous powers and, incidentally, could begin the end of life on Middle Earth. The warrior Aragorn (Viggo Mortensen) has been inflated into an even more assured, reflexive action hero. He helps a bewitched king (Bernard Hill) defend his castle. The action sequences are even more compelling than the first time around; we could be watching Orson Welles's &quot;Chimes at Midnight&quot; as directed by George A. Romero — Shakespearean-scale bloodshed and loss as an exploitation movie. There are flaws, particularly the family-oriented video-game aspects, which offer no emotional complications other than saving the day. — Elvis Mitchell",
#   'publication_date': '2002-12-18',
#   'opening_date': '2002-12-18',
#   'date_updated': '2017-11-02 04:18:01',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2002/12/18/movies/film-review-soldiering-on-in-epic-pursuit-of-purity.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lord of the Rings: The Two Towers'},
#   'multimedia': None},
#  {'display_title': 'The Matrix Revolutions',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'A. O. SCOTT',
#   'headline': 'The Game Concludes With Light and Noise',
#   'summary_short': '&quot;Everything that has a beginning has an end.&quot; Yes, thank God — or Neo, or the One, or the Source, or the Oracle, or the Architect, or whoever it was who set this metaphysical action trilogy in motion. &quot;Reloaded,&quot; the second installment, was overstuffed and ungainly; this concluding chapter feels padded, with a long, grinding battle sequence in the middle and a whole lot of mumbo-jumbo at the end. Keanu Reeves, perhaps worried that he was showing too much range, has purged himself of all expression apart from a worried frown and a sorrowful grimace, which is mirrored in the face of Carrie-Anne Moss, who returns as Trinity. The salient distinction of the human remnants in Zion, apart from their earth-toned natural-fiber fashions, has been the capacity for love, a word much spoken in this movie. But their ranks, in spite of the presence of fine actors like Laurence Fishburne, Harry Lennix and Harold Perrineau, become more robotic with every passing scene. The sole exception is Jada Pinkett Smith as the daredevil pilot Niobe, who brings a touch of bad-girl B-movie attitude into the humorless subterranean gloom. It is not altogether worthless: the Wachowski Brothers still know how to stage an action sequence, and there are some scenes that have a quiet, mysterious beauty. If they would only let go of their grandiose theological pretensions, they might once again be interesting filmmakers. — A. O. Scott',
#   'publication_date': '2003-11-05',
#   'opening_date': '2003-11-05',
#   'date_updated': '2017-11-02 04:18:03',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2003/11/05/movies/film-review-the-game-concludes-with-light-and-noise.html',
#    'suggested_link_text': 'Read the New York Times Review of The Matrix Revolutions'},
#   'multimedia': None},
#  {'display_title': 'Goodfellas',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Vincent Canby',
#   'headline': 'GOODFELLAS (MOVIE)',
#   'summary_short': "Pileggi-Scorsese's Mafia. Cold-eyed, breathless, brilliant.",
#   'publication_date': '1990-09-19',
#   'opening_date': '1990-09-21',
#   'date_updated': '2017-11-02 04:17:42',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1990/09/19/movies/review-film-a-cold-eyed-look-at-the-mob-s-inner-workings.html',
#    'suggested_link_text': 'Read the New York Times Review of Goodfellas'},
#   'multimedia': None},
#  {'display_title': "One Flew Over the Cuckoo's Nest",
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'VINCENT CANBY',
#   'headline': "One Flew Over the Cuckoo's Nest (Movie)",
#   'summary_short': 'Piercing drama of mental institution. Five Oscars, including best picture.',
#   'publication_date': '1975-11-20',
#   'opening_date': '1975-11-21',
#   'date_updated': '2017-11-02 04:17:27',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1975/11/20/archives/israeli-reconnaisance-jets-fly-over-beirut-stir-fear-of-attack.html',
#    'suggested_link_text': "Read the New York Times Review of One Flew Over the Cuckoo's Nest"},
#   'multimedia': None},
#  {'display_title': 'Seven',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'SEVEN (MOVIE)',
#   'summary_short': 'Murders based on seven deadly sins. Deadly dull.',
#   'publication_date': '1995-09-22',
#   'opening_date': '1995-09-22',
#   'date_updated': '2017-11-02 04:17:49',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1995/09/22/movies/film-review-a-sickening-catalogue-of-sins-every-one-of-them-deadly.html',
#    'suggested_link_text': 'Read the New York Times Review of Seven'},
#   'multimedia': None},
#  {'display_title': "It's a Wonderful Life",
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'BOSLEY CROWTHER',
#   'headline': "It's a Wonderful Life",
#   'summary_short': "Suicidal family man saved by guardian angel. Capra's cast-iron cheer will hook you.",
#   'publication_date': '1946-12-23',
#   'opening_date': '1947-01-07',
#   'date_updated': '2017-11-02 04:17:09',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1946/12/23/archives/the-screen-in-review-at-three-theatres-its-a-wonderful-life-with.html',
#    'suggested_link_text': "Read the New York Times Review of It's a Wonderful Life"},
#   'multimedia': None},
#  {'display_title': 'Star Wars: The Rise of Skywalker',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'A.O. Scott',
#   'headline': '‘Star Wars: The Rise of Skywalker’ Review: Revolution No. 9',
#   'summary_short': 'Resistance is futile. Rey, Finn and Poe are back; so is Kylo Ren. No spoilers here.',
#   'publication_date': '2019-12-18',
#   'opening_date': '2019-12-20',
#   'date_updated': '2020-01-18 17:44:01',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/12/18/movies/star-wars-the-rise-of-skywalker-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Star Wars: The Rise of Skywalker'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/12/18/arts/18riseofskywalker1/18riseofskywalker1-mediumThreeByTwo210-v2.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Saving Private Ryan',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'Saving Private Ryan (Movie)  ',
#   'summary_short': 'World War II squad risks all to find one soldier. Magnificent.',
#   'publication_date': '1998-07-24',
#   'opening_date': '1998-07-24',
#   'date_updated': '2017-11-02 04:17:55',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1998/07/24/movies/film-review-panoramic-and-personal-visions-of-war-s-anguish.html',
#    'suggested_link_text': 'Read the New York Times Review of Saving Private Ryan'},
#   'multimedia': None},
#  {'display_title': 'River City Drumbeat',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'Teo Bugbee',
#   'headline': '‘River City Drumbeat’ Review: A Community’s Pulse Proves Strong',
#   'summary_short': 'At the heart of this documentary from Marlon Johnson and Anne Flatté is a drum line in Louisville, Ky., that offers children a chance to engage with Black art and history.',
#   'publication_date': '2020-08-06',
#   'opening_date': None,
#   'date_updated': '2020-08-07 05:06:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2020/08/06/movies/river-city-drumbeat-review.html',
#    'suggested_link_text': 'Read the New York Times Review of River City Drumbeat'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2020/08/07/arts/06rivercity-art/06rivercity-art-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'The Green Mile',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'Green Mile, The (Movie)',
#   'summary_short': 'Gentle-giant healer on death row. Moving performances, durable storytelling.',
#   'publication_date': '1999-12-10',
#   'opening_date': '1999-12-10',
#   'date_updated': '2017-11-02 04:17:57',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1999/12/10/movies/film-review-the-walk-on-death-row-can-seem-very-long.html',
#    'suggested_link_text': 'Read the New York Times Review of The Green Mile'},
#   'multimedia': None},
#  {'display_title': 'Interstellar',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Off to the Stars, With Grief, Dread and Regret',
#   'summary_short': 'In Christopher Nolan’s science-fiction parable “Interstellar,” Earth is dying, and a team of astronauts searches the universe for a new home for the human race.',
#   'publication_date': '2014-11-04',
#   'opening_date': '2014-11-07',
#   'date_updated': '2017-11-02 04:18:20',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2014/11/05/movies/interstellar-christopher-nolans-search-for-a-new-planet.html',
#    'suggested_link_text': 'Read the New York Times Review of Interstellar'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2014/11/05/arts/interstellar-1/interstellar-1-mediumThreeByTwo210-v2.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Song Without a Name',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'Teo Bugbee',
#   'headline': '‘Song Without a Name’ Review: A Tragedy in the Peruvian Hillside',
#   'summary_short': 'Melina León’s beautifully composed film follows a woman whose baby was stolen from her after child birth.',
#   'publication_date': '2020-08-06',
#   'opening_date': None,
#   'date_updated': '2020-08-06 11:04:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2020/08/06/movies/song-without-a-name-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Song Without a Name'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2020/08/07/arts/06songwithout/merlin_175178241_ba2ab76f-0747-4661-81b1-216854b33048-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Anna Karenina (Bolshoi Ballet)',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'ANNA KISSELGOFF',
#   'headline': 'Anna Karenina (Movie)',
#   'summary_short': 'Bolshoi Ballet version of Tolstoy.',
#   'publication_date': '1979-12-15',
#   'opening_date': '1995-09-15',
#   'date_updated': '2017-11-02 04:17:49',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1979/12/15/archives/screen-4-dances-by-the-bolshoi-ballet-at-the-beacon-the-program.html',
#    'suggested_link_text': 'Read the New York Times Review of Anna Karenina (Bolshoi Ballet)'},
#   'multimedia': None},
#  {'display_title': 'The Lion King',
#   'mpaa_rating': 'PG',
#   'critics_pick': 0,
#   'byline': 'A.O. SCOTT',
#   'headline': '‘The Lion King’ Review: The Art of Herding Digital Cats',
#   'summary_short': 'Beyoncé, Donald Glover and Seth Rogen are some of the famous voices in a super-realistic version of the Disney and Broadway favorite.',
#   'publication_date': '2019-07-11',
#   'opening_date': '2019-07-19',
#   'date_updated': '2019-08-11 16:44:01',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/07/11/movies/the-lion-king-review.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lion King'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/07/11/arts/11lionking1/11lionking1-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Back to the Future III',
#   'mpaa_rating': 'PG',
#   'critics_pick': 0,
#   'byline': 'Vincent Canby',
#   'headline': 'BACK TO THE FUTURE, PART III (MOVIE)',
#   'summary_short': 'Wild and woolly West of 1885. Cheerful, sweet and forgettable.',
#   'publication_date': '1990-05-25',
#   'opening_date': '1990-05-25',
#   'date_updated': '2017-11-02 04:17:41',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1990/05/25/movies/review-film-a-trilogy-whose-future-has-passed.html',
#    'suggested_link_text': 'Read the New York Times Review of Back to the Future III'},
#   'multimedia': None},
#  {'display_title': 'The Pianist',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. Scott',
#   'headline': 'Pianist, The (Movie)  ',
#   'summary_short': "Roman Polanski, filming in Poland for the first time in 40 years, has made one of the finest films yet about the catastrophe the Nazis visited on Poland and its Jewish population. Adrien Brody, in a fluid, understated and thoroughly unsentimental performance, plays Wladislaw Szpilman, a popular concert pianist who survived, against odds that can only be described as absurd, the German occupation of Warsaw and the inferno of the city's Jewish ghetto. With relentless clarity, Mr. Polanski tracks the deterioration of his hero's situation and the day-in, day-out assault on his humanity. There are scenes of unwatchable brutality as well as of kindness and solidarity, but what is most remarkable is the sense of daily life in impossible conditions. The last part of the movie, in which Szpilman is first trapped in a safe house and then condemned to wander the bombed-out city, is a tour de force, at once harrowing and strangely comic. — A. O. Scott",
#   'publication_date': '2002-12-27',
#   'opening_date': '2003-03-28',
#   'date_updated': '2017-11-02 04:18:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2002/12/27/movies/film-review-surviving-the-warsaw-ghetto-against-steep-odds.html',
#    'suggested_link_text': 'Read the New York Times Review of The Pianist'},
#   'multimedia': None},
#  {'display_title': 'Terminator 2: Judgment Day',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'TERMINATOR 2: JUDGMENT DAY (MOVIE)',
#   'summary_short': "Now he's the good guy. Fast, exciting special-effects epic.",
#   'publication_date': '1991-07-03',
#   'opening_date': '1991-07-03',
#   'date_updated': '2017-11-02 04:17:43',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1991/07/03/movies/review-film-in-new-terminator-the-forces-of-good-seek-peace-violently.html',
#    'suggested_link_text': 'Read the New York Times Review of Terminator 2: Judgment Day'},
#   'multimedia': None},
#  {'display_title': 'American History X',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'American History X (Movie)  ',
#   'summary_short': 'Reformed skinhead and neo-Nazi brother. Inflated, but knows which nerves to hit.',
#   'publication_date': '1998-10-28',
#   'opening_date': '1998-11-20',
#   'date_updated': '2017-11-02 04:17:56',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1998/10/28/movies/film-review-the-darkest-chambers-of-a-nation-s-soul.html',
#    'suggested_link_text': 'Read the New York Times Review of American History X'},
#   'multimedia': None},
#  {'display_title': 'Modern Times',
#   'mpaa_rating': 'G',
#   'critics_pick': 0,
#   'byline': 'FRANK S. NUGENT.',
#   'headline': 'Modern Times',
#   'summary_short': 'The Little Tramp vs. the Assembly Line. Priceless.',
#   'publication_date': '1936-02-06',
#   'opening_date': '1936-02-25',
#   'date_updated': '2017-11-02 04:16:58',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1936/02/06/archives/heralding-the-return-after-an-undue-absence-of-charlie-chaplin-in.html',
#    'suggested_link_text': 'Read the New York Times Review of Modern Times'},
#   'multimedia': None},
#  {'display_title': 'SHOT! The Psycho-Spiritual Mantra of Rock',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'GLENN KENNY',
#   'headline': 'Review: ‘SHOT!,’ About the Man Who Captured Rock’s Famous Faces',
#   'summary_short': 'Mick Rock, the British photographer with the cool name and starry portfolio (Blondie, Lou Reed, David Bowie) is the subject of a new documentary.',
#   'publication_date': '2017-04-05',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:41',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2017/04/05/movies/shot-the-psycho-spiritual-mantra-of-rock-review.html',
#    'suggested_link_text': 'Read the New York Times Review of SHOT! The Psycho-Spiritual Mantra of Rock'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2017/04/07/arts/07shotrock1/07shotrock1-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'The Last Gladiators',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'NICOLAS RAPOLD',
#   'headline': 'Always Carrying a Big Stick',
#   'summary_short': 'In the documentary “The Last Gladiators,” Alex Gibney Shows the tough-guy caste in hockey.',
#   'publication_date': '2013-01-31',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:37',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2013/02/01/movies/alex-gibneys-last-gladiators-looks-at-hockeys-tough-guys.html',
#    'suggested_link_text': 'Read the New York Times Review of The Last Gladiators'},
#   'multimedia': None},
#  {'display_title': 'City Lights',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'MORDAUNT HALL.',
#   'headline': 'City Lights',
#   'summary_short': 'Little Tramp loves blind flower vendor. One of the great ones.',
#   'publication_date': '1931-02-07',
#   'opening_date': '1931-03-07',
#   'date_updated': '2017-11-02 04:16:50',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1931/02/07/archives/chaplin-hilarious-in-his-city-lights-tramps-antics-in-nondialogue.html',
#    'suggested_link_text': 'Read the New York Times Review of City Lights'},
#   'multimedia': None},
#  {'display_title': 'The Departed',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'MANOHLA DARGIS',
#   'headline': 'Scorsese’s Hall of Mirrors, Littered With Bloody Deceit',
#   'summary_short': "Martin Scorsese's cubistic entertainment about men divided by power, loyalty and their own selves is at once a success and a relief.",
#   'publication_date': '2006-10-06',
#   'opening_date': '2006-10-06',
#   'date_updated': '2017-11-02 04:18:04',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2006/10/06/movies/06depa.html',
#    'suggested_link_text': 'Read the New York Times Review of The Departed'},
#   'multimedia': None},
#  {'display_title': 'The Untouchables',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Helping a White Man Relearn Joie de Vivre',
#   'summary_short': '“The Intouchables” is an ingratiating French comedy of cross-racial friendship.',
#   'publication_date': '2012-05-24',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:34',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2012/05/25/movies/the-intouchables-arrives-from-france.html',
#    'suggested_link_text': 'Read the New York Times Review of The Untouchables'},
#   'multimedia': None},
#  {'display_title': 'Whiplash',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Drill Sergeant in the Music Room ',
#   'summary_short': 'Damien Chazelle&#8217;s &#8220;Whiplash&#8221; is a movie about music, but it could just as well have been about an underdog sports team.',
#   'publication_date': '2014-10-09',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:40',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2014/10/10/movies/in-whiplash-a-young-jazz-drummer-vs-his-teacher.html',
#    'suggested_link_text': 'Read the New York Times Review of Whiplash'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2014/10/10/arts/whiplash/whiplash-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'The Prestige',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Two Rival Magicians, and Each Wants the Other to Go Poof',
#   'summary_short': 'Entertaining, spirited and shamelessly gimmicky, Christopher Nolan’s film tells the intricate tale of two rival magicians practicing their art in late-Victorian London. ',
#   'publication_date': '2006-10-20',
#   'opening_date': '2006-10-20',
#   'date_updated': '2017-11-02 04:18:04',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2006/10/20/movies/20pres.html',
#    'suggested_link_text': 'Read the New York Times Review of The Prestige'},
#   'multimedia': None},
#  {'display_title': 'Once Upon a Time in the West',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'VINCENT CANBY',
#   'headline': 'Once Upon the Time in the West (Movie)',
#   'summary_short': 'Beautiful widow with a price on her head. Boldly dark, jagged western, the Sergio Leone way.',
#   'publication_date': '1969-05-29',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:15:59',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1969/05/29/archives/once-upon-the-time-in-west.html',
#    'suggested_link_text': 'Read the New York Times Review of Once Upon a Time in the West'},
#   'multimedia': None},
#  {'display_title': 'America the Beautiful',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'JEANNETTE CATSOULIS',
#   'headline': 'What You See',
#   'summary_short': 'Clueless, directionless and altogether pointless, “America the Beautiful” will outrage only those who have spent the last 50 years in suspended animation.',
#   'publication_date': '2008-08-01',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:28',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2008/08/01/movies/01beau.html',
#    'suggested_link_text': 'Read the New York Times Review of America the Beautiful'},
#   'multimedia': None},
#  {'display_title': 'Rear Window',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 0,
#   'byline': 'JANET MASLIN',
#   'headline': 'Rear Window (Movie)',
#   'summary_short': 'Housebond voyeur suspects neighbor of murder. Tasteful, engaging update of Hitchcock classic.',
#   'publication_date': '1983-10-09',
#   'opening_date': '1998-11-22',
#   'date_updated': '2017-11-02 04:17:56',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1983/10/09/movies/and-james-stewart-recalls-hitch.html',
#    'suggested_link_text': 'Read the New York Times Review of Rear Window'},
#   'multimedia': None},
#  {'display_title': 'Memory: The Origins of Alien',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'BEN KENIGSBERG',
#   'headline': '‘Memory: The Origins of Alien’ Review: Extras on an Extraterrestrial',
#   'summary_short': 'This documentary about Ridley Scott’s 1979 science-fiction classic often plays like a conventional making-of doc.',
#   'publication_date': '2019-10-03',
#   'opening_date': '2019-10-04',
#   'date_updated': '2019-10-11 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/10/03/movies/memory-the-origins-of-alien-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Memory: The Origins of Alien'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/10/04/arts/03memory-art/03memory-art-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Memento',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. Scott',
#   'headline': 'Memento (Movie)  ',
#   'summary_short': "A dazzling feat of narrative sleight-of-hand, &quot;Memento&quot; runs its film-noir revenge plot in reverse. Guy Pearce plays an insurance investigator afflicted with short-term amnesia (&quot;I can't make new memories,&quot; he explains), trying to track down his wife's murderer with the help of a sheaf of Polaroids, a chest full of tattoos and a couple of shady characters (Joe Pantoliano and Carrie-Anne Moss). The movie, a triumph of directorial style, is challenging and suspenseful, even if, in the end, nothing more than formal bravura seems to be at stake. — A. O. Scott",
#   'publication_date': '2001-03-16',
#   'opening_date': '2001-05-25',
#   'date_updated': '2017-11-02 04:17:59',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2001/03/16/movies/film-review-backward-reel-the-grisly-memories.html',
#    'suggested_link_text': 'Read the New York Times Review of Memento'},
#   'multimedia': None},
#  {'display_title': 'Raiders of the Lost Ark',
#   'mpaa_rating': 'PG',
#   'critics_pick': 1,
#   'byline': 'Vincent Canby',
#   'headline': 'RAIDERS OF THE LOST ARK (MOVIE)',
#   'summary_short': 'Indiana Jones, serial-adventure-style hero. Rousing fun, with no lulls.',
#   'publication_date': '1981-06-12',
#   'opening_date': '1981-06-12',
#   'date_updated': '2017-11-02 04:17:30',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1981/06/12/movies/raiders-of-lost-ark.html',
#    'suggested_link_text': 'Read the New York Times Review of Raiders of the Lost Ark'},
#   'multimedia': None},
#  {'display_title': 'The Great Dictator',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'BOSLEY CROWTHER',
#   'headline': 'Great Dictator, The',
#   'summary_short': "Jewish barber and Hitler look-alike. Chaplin's comic gem.",
#   'publication_date': '1940-10-16',
#   'opening_date': '1941-03-07',
#   'date_updated': '2017-11-02 04:17:03',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1940/10/16/archives/the-screen-in-review-the-great-dictator-by-and-with-charlie-chaplin.html',
#    'suggested_link_text': 'Read the New York Times Review of The Great Dictator'},
#   'multimedia': None},
#  {'display_title': 'Joker',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'A.O. Scott',
#   'headline': '‘Joker’ Review: Are You Kidding Me?',
#   'summary_short': 'Todd Phillips’s supervillain origin story starring Joaquin Phoenix is stirring up a fierce debate, but it’s not interesting enough to argue about.',
#   'publication_date': '2019-10-03',
#   'opening_date': '2019-10-04',
#   'date_updated': '2019-11-03 17:44:01',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/10/03/movies/joker-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Joker'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/10/05/arts/04Joker-Cover/merlin_161549496_c55020b5-50f8-432b-a141-64fea126a42b-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'The Lives of Others',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'A Fugue for Good German Men',
#   'summary_short': '“The Lives of Others” is a supremely intelligent, unfailingly honest look at a shadowy period in recent German history.',
#   'publication_date': '2007-02-09',
#   'opening_date': '2007-03-30',
#   'date_updated': '2017-11-02 04:18:05',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2007/02/09/movies/09live.html',
#    'suggested_link_text': 'Read the New York Times Review of The Lives of Others'},
#   'multimedia': None},
#  {'display_title': 'Django Unchained',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'The Black, the White and the Angry',
#   'summary_short': '“Django Unchained” is pulpy, digressive, jokey, giddily brutal and ferociously profane, but it is also a troubling and important movie about slavery and racism.',
#   'publication_date': '2012-12-24',
#   'opening_date': '2012-12-25',
#   'date_updated': '2017-11-02 04:18:16',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2012/12/25/movies/quentin-tarantinos-django-unchained-stars-jamie-foxx.html',
#    'suggested_link_text': 'Read the New York Times Review of Django Unchained'},
#   'multimedia': None},
#  {'display_title': 'Paths of Glory',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'BOSLEY CROWTHER',
#   'headline': 'Paths of Glory',
#   'summary_short': 'WWI French soldiers, via Kubrick. Scalding.',
#   'publication_date': '1957-12-26',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:15:54',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1957/12/26/archives/screen-shameful-incident-of-war-paths-of-glory-has-premiere-at.html',
#    'suggested_link_text': 'Read the New York Times Review of Paths of Glory'},
#   'multimedia': None},
#  {'display_title': 'The Shining',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'THE SHINING (MOVIE)',
#   'summary_short': 'Remote off-season hotel turns evil. Real chiller, the Kubrick way.',
#   'publication_date': '1980-05-23',
#   'opening_date': '1980-05-23',
#   'date_updated': '2017-11-02 04:17:29',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1980/05/23/archives/screen-nicholson-and-shelley-duvall-in-kubricks-the-shining-horror.html',
#    'suggested_link_text': 'Read the New York Times Review of The Shining'},
#   'multimedia': None},
#  {'display_title': 'WALL-E',
#   'mpaa_rating': 'G',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'In a World Left Silent, One Heart Beeps',
#   'summary_short': '“Wall-E” breaks new ground in giving us a G-rated, computer-generated cartoon vision of our own potential extinction.',
#   'publication_date': '2008-06-27',
#   'opening_date': '2008-06-27',
#   'date_updated': '2017-11-02 04:18:08',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2008/06/27/movies/27wall.html',
#    'suggested_link_text': 'Read the New York Times Review of WALL-E'},
#   'multimedia': None},
#  {'display_title': 'Avengers: Infinity War',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'A.O. SCOTT',
#   'headline': '‘Avengers: Infinity War’: It’s Marvel’s Universe. We Just Live in It.',
#   'summary_short': 'Infinity? Come on. It’s not even three hours! But there is enough time to get a hunky-Chris showdown (Pratt vs. Hemsworth vs. Evans).',
#   'publication_date': '2018-04-24',
#   'opening_date': '2018-04-27',
#   'date_updated': '2018-05-24 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2018/04/24/movies/avengers-infinity-war-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Avengers: Infinity War'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2018/04/27/arts/27avengers/27avengers-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Spider-Man: Into the Spider-Verse',
#   'mpaa_rating': 'PG',
#   'critics_pick': 1,
#   'byline': 'A.O. SCOTT',
#   'headline': '‘Spider-Man: Into the Spider-Verse’ Review: A Fresh Take on a Venerable Hero',
#   'summary_short': 'This lively, diverse comic-book movie brings some fun to a genre that often takes itself too seriously.',
#   'publication_date': '2018-12-12',
#   'opening_date': '2018-12-14',
#   'date_updated': '2019-01-12 17:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2018/12/12/movies/spider-man-into-the-spider-verse-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Spider-Man: Into the Spider-Verse'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2018/12/14/arts/14spiderman/14spiderman-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Witness For the Prosecution',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'BOSLEY CROWTHER',
#   'headline': 'Witness for the Prosecution',
#   'summary_short': "Classy, juicy version of Christie's stage puzzler, via Billy Wilder. Keep your eye on Marlene.",
#   'publication_date': '1958-02-07',
#   'opening_date': '1958-02-06',
#   'date_updated': '2017-11-02 04:17:18',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1958/02/07/archives/screen-witness-for-the-prosecution-laughton-is-starred-in-courtroom.html',
#    'suggested_link_text': 'Read the New York Times Review of Witness For the Prosecution'},
#   'multimedia': None},
#  {'display_title': 'Dr. Strangelove',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'Bosley Crowther',
#   'headline': 'DR. STRANGELOVE OR: HOW I LEARNED TO STOP WORRYING AND LOVE THE BOMB (MOVIE)',
#   'summary_short': "Kubrick's fantasy-satire on the H-bomb. Wild, funny, brilliant, horrifying.",
#   'publication_date': '1964-01-31',
#   'opening_date': '1964-01-29',
#   'date_updated': '2017-11-02 04:17:21',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1964/01/30/archives/kubrick-film-presents-sellers-in-3-roles.html',
#    'suggested_link_text': 'Read the New York Times Review of Dr. Strangelove'},
#   'multimedia': None},
#  {'display_title': 'The Dark Knight Rises',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'MANOHLA DARGIS',
#   'headline': 'A Rejected Superhero Ends Up at Ground Zero',
#   'summary_short': 'Christopher Nolan’s “Dark Knight Rises” wraps up his post-Sept. 11 epic of ambivalent good vs. multidimensional evil with a burst of light.',
#   'publication_date': '2012-07-18',
#   'opening_date': '2012-07-20',
#   'date_updated': '2017-11-02 04:18:15',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2012/07/20/movies/the-dark-knight-rises-with-christian-bale.html',
#    'suggested_link_text': 'Read the New York Times Review of The Dark Knight Rises'},
#   'multimedia': None},
#  {'display_title': 'Once Upon A Time In America',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Vincent Canby',
#   'headline': 'ONCE UPON A TIME IN AMERICA (MOVIE)',
#   'summary_short': 'Gangster reminisces. Brooding, vivid, often spellbinding.',
#   'publication_date': '1984-06-01',
#   'opening_date': '1984-06-01',
#   'date_updated': '2017-11-02 04:17:33',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1984/06/01/movies/film-once-upon-a-time-inamerica.html',
#    'suggested_link_text': 'Read the New York Times Review of Once Upon A Time In America'},
#   'multimedia': None},
#  {'display_title': 'Avengers: Endgame',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'A.O. SCOTT',
#   'headline': '‘Avengers: Endgame’ Review: The Real Heroes Were the Friends We Made Along the Way',
#   'summary_short': 'Iron Man, Thor, the Hulk, Captain America and other stars settle scores, tie up loose ends and take a long victory lap in the final chapter of this cycle.',
#   'publication_date': '2019-04-23',
#   'opening_date': '2019-04-26',
#   'date_updated': '2019-05-23 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/04/23/movies/avengers-endgame-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Avengers: Endgame'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/04/23/arts/23avengers-hp-promo/23avengers-hp-promo-mediumThreeByTwo210-v5.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Cocote',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'GLENN KENNY',
#   'headline': 'Review: In ‘Cocote,’ an Ambitious Director Undercuts His Simple Story',
#   'summary_short': 'A pious man is asked to avenge his murdered father in the fictional feature debut of the Dominican filmmaker Nelson Carlo de Los Santos Arias.',
#   'publication_date': '2018-08-02',
#   'opening_date': None,
#   'date_updated': '2018-08-10 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2018/08/02/movies/cocote-review-dominican-republic.html',
#    'suggested_link_text': 'Read the New York Times Review of Cocote'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2018/08/03/arts/03COCOTE-1/03COCOTE-1-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'American Beauty',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Janet Maslin',
#   'headline': 'American Beauty (Movie)  ',
#   'summary_short': "With heavenly finesse Kevin Spacey plays a buttoned-down 42-year-old suburbanite who flips his lid for a teenage cheerleader. And he never gets it back on. The midlife crisis motif is familiar, but the stage director Sam Mendes brings terrific visual flair and dry humor to this barbecuing of the bourgeoisie. All the actors display coolly expert timing, especially Annette Bening as the antihero's grasping wife. Although the story spreads itself thin among many characters, the film coalesces for a devastating finale. &#151; Janet Maslin\n",
#   'publication_date': '1999-09-15',
#   'opening_date': '1999-10-01',
#   'date_updated': '2017-11-02 04:17:57',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1999/09/15/movies/film-review-dad-s-dead-and-he-s-still-a-funny-guy.html',
#    'suggested_link_text': 'Read the New York Times Review of American Beauty'},
#   'multimedia': None},
#  {'display_title': 'Braveheart',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Caryn James',
#   'headline': 'BRAVEHEART (MOVIE)',
#   'summary_short': '13th-century Scots in revolt against England. Won best picture Oscar. Spectacular.',
#   'publication_date': '1995-05-24',
#   'opening_date': '1995-05-24',
#   'date_updated': '2017-11-02 04:17:48',
#   'link': {'type': 'article',
# ...
#   'multimedia': None},
#  {'display_title': 'Wasp Network',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'Glenn Kenny',
#   'headline': '‘Wasp Network’ Review: Fleeing Cuba With Loyalties in Question',
#   'summary_short': 'Olivier Assayas has created his most mainstream film yet, a spy story replete with double-crosses and romance.',
#   'publication_date': '2020-06-18',
#   'opening_date': '2020-06-19',
#   'date_updated': '2020-06-18 11:04:04',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2020/06/18/movies/wasp-network-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Wasp Network'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2020/06/19/arts/18waspnetwork/18waspnetwork-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Cool Hand Luke',
#   'mpaa_rating': 'PG',
#   'critics_pick': 1,
#   'byline': 'BOSLEY CROWTHER',
#   'headline': 'Cool Hand Luke',
#   'summary_short': 'Chain-gang convict. Brutal and memorable.',
#   'publication_date': '1967-11-02',
#   'opening_date': '1967-11-01',
#   'date_updated': '2017-11-02 04:17:23',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1967/11/02/archives/screen-forceful-portrait-of-a-man-born-to-losepaul-newman-superb-as.html',
#    'suggested_link_text': 'Read the New York Times Review of Cool Hand Luke'},
#   'multimedia': None},
#  {'display_title': 'Into the Wild',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Following His Trail to Danger and Joy',
#   'summary_short': 'There is plenty of sorrow to be found in “Into the Wild.” But though the film’s structure may be tragic, its spirit is anything but. ',
#   'publication_date': '2007-09-21',
#   'opening_date': '2007-10-19',
#   'date_updated': '2017-11-02 04:18:06',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2007/09/21/movies/21wild.html',
#    'suggested_link_text': 'Read the New York Times Review of Into the Wild'},
#   'multimedia': None},
#  {'display_title': 'Ben-Hur',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'STEPHEN HOLDEN',
#   'headline': 'Review: ‘Ben-Hur’ Is a Savage Update for a New Generation',
#   'summary_short': 'Timur Bekmambetov’s adaptation of the sword-and-sandals spectacle offers a rip-roaring chariot race but is largely devoid of pious posturing.',
#   'publication_date': '2016-08-18',
#   'opening_date': '2016-08-19',
#   'date_updated': '2017-11-02 04:18:25',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2016/08/19/movies/ben-hur-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Ben-Hur'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2016/08/19/arts/19BENHUR1/19BENHUR1-mediumThreeByTwo210-v2.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Dead Poets Society',
#   'mpaa_rating': 'PG',
#   'critics_pick': 0,
#   'byline': 'Vincent Canby',
#   'headline': 'DEAD POETS SOCIETY (MOVIE)',
#   'summary_short': 'Hip Mr. Chips. Predictable, but fine Williams.',
#   'publication_date': '1989-06-02',
#   'opening_date': '1989-06-09',
#   'date_updated': '2017-11-02 04:17:40',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1989/06/02/movies/review-film-shaking-up-a-boys-school-with-poetry.html',
#    'suggested_link_text': 'Read the New York Times Review of Dead Poets Society'},
#   'multimedia': None},
#  {'display_title': 'The 317th Platoon',
#   'mpaa_rating': '',
#   'critics_pick': 1,
#   'byline': 'GLENN KENNY',
#   'headline': 'Review: The Vietnam War, as Fought by the French, in ‘The 317th Platoon’',
#   'summary_short': 'This revelatory French-made film, shot in the 1960s and directed by the former war photographer Pierre Schoendoerffer, gets a New York premiere.',
#   'publication_date': '2018-08-09',
#   'opening_date': None,
#   'date_updated': '2018-08-16 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2018/08/09/movies/the-317th-platoon-review-vietnam-war.html',
#    'suggested_link_text': 'Read the New York Times Review of The 317th Platoon'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2018/08/10/movies/10platoon1/10platoon1-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': "Monty Python's Life Of Brian",
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'VINCENT CANBY',
#   'headline': "Monty Python's Life of Brian (Movie)",
#   'summary_short': 'Scriptural satire, with an anvil.',
#   'publication_date': '1979-08-17',
#   'opening_date': '1979-08-17',
#   'date_updated': '2017-11-02 04:17:29',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1979/08/17/archives/film-monty-pythons-life-of-brian-gospel-of-lunacy.html',
#    'suggested_link_text': "Read the New York Times Review of Monty Python's Life Of Brian"},
#   'multimedia': None},
#  {'display_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 1,
#   'byline': 'MANOHLA DARGIS',
#   'headline': 'Class Dismissed',
#   'summary_short': 'Childhood ends with tears and howls and swirls of smoke, the shock of mortality and bittersweet smiles in the grave, deeply satisfying final movie in the “Harry Potter” series.',
#   'publication_date': '2011-07-13',
#   'opening_date': '2011-07-15',
#   'date_updated': '2017-11-02 04:18:13',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2011/07/15/movies/harry-potter-and-the-deathly-hallows-part-2-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Harry Potter and the Deathly Hallows: Part 2'},
#   'multimedia': None},
#  {'display_title': 'Shirley',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'A.O. Scott',
#   'headline': '‘Shirley’ Review: A Writer as Scary as Her Stories',
#   'summary_short': 'Elisabeth Moss stars as Shirley Jackson in Josephine Decker’s gothic, feverish anti-biopic.',
#   'publication_date': '2020-06-03',
#   'opening_date': '2020-06-05',
#   'date_updated': '2020-06-03 20:10:03',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2020/06/03/movies/shirley-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Shirley'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2020/06/05/arts/00shirley/00shirley-mediumThreeByTwo210-v2.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Storm Boy',
#   'mpaa_rating': 'PG',
#   'critics_pick': 0,
#   'byline': 'TEO BUGBEE',
#   'headline': '‘Storm Boy’ Review: Raising Pelicans in a Film That Never Fully Takes Flight',
#   'summary_short': 'The film tries to present itself as a modern fable, but the themes come across as didactic rather than moving.',
#   'publication_date': '2019-04-04',
#   'opening_date': '2019-04-05',
#   'date_updated': '2019-04-12 16:44:02',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2019/04/04/movies/storm-boy-review.html',
#    'suggested_link_text': 'Read the New York Times Review of Storm Boy'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2019/04/04/arts/04stormboy/merlin_152839785_79db8663-673e-4665-a7a4-75c324a1a3a1-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Andrei Roublev',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 0,
#   'byline': 'VINCENT CANBY',
#   'headline': 'Andrei Rublev (Movie)',
#   'summary_short': '15th-century Russian icon painter renounces his art. A Tarkovsky masterpiece.',
#   'publication_date': '1973-10-10',
#   'opening_date': '1973-00-00',
#   'date_updated': '2017-11-02 04:17:26',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1973/10/10/archives/film-fete-andrei-rublev-from-russia-is-shown-the-cast.html',
#    'suggested_link_text': 'Read the New York Times Review of Andrei Roublev'},
#   'multimedia': None},
#  {'display_title': 'Spotlight',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. SCOTT',
#   'headline': 'Review: In ‘Spotlight,’ The Boston Globe Digs Up the Catholic Church’s Dirt ',
#   'summary_short': 'In this gripping detective story, a small group of reporters exposes the church’s role in covering up the sexual abuse of children by priests.',
#   'publication_date': '2015-11-05',
#   'opening_date': '2015-11-25',
#   'date_updated': '2017-11-02 04:18:23',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2015/11/06/movies/review-in-spotlight-the-boston-globe-digs-up-the-catholic-churchs-dirt.html',
#    'suggested_link_text': 'Read the New York Times Review of Spotlight'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2015/11/05/arts/06spotlight/06spotlight-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Amores Perros',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'Elvis Mitchell',
#   'headline': 'Amores Perros (Movie)  ',
#   'summary_short': 'When a director shifts gears as often as does Alejandro Gonzalez Inarritu, the man behind the emotionally rich debut film &quot;Amores Perros,&quot; you may wonder if he knows what he wants. He does, and this film is satisfying in many ways. He is unashamed to immerse this tough-minded, episodic film noir in freshets of melodrama. Significantly, he knows the minute difference between being unashamed and being shameless, and because he knows how to keep things hopping   —   working from an intricate script by Guillermo Arrianga that has a novelistic texture   —   we watch a man with immaculate control of the medium. — Elvis Mitchell',
#   'publication_date': '2000-10-05',
#   'opening_date': '2001-04-13',
#   'date_updated': '2017-11-02 04:17:59',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2000/10/05/movies/film-festival-review-mexico-3-stories-array-lives-united-car-wreck.html',
#    'suggested_link_text': 'Read the New York Times Review of Amores Perros'},
#   'multimedia': None},
#  {'display_title': 'Blood Brother',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 1,
#   'byline': 'DAVID DeWITT',
#   'headline': 'Where Love Coexists With Death',
#   'summary_short': 'A documentary by a first-time filmmaker, Steve Hoover, about a friend who finds his life’s work at a home for H.I.V.-positive children in India.',
#   'publication_date': '2013-10-17',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:38',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2013/10/18/movies/blood-brother-about-a-heart-bound-to-children-with-hiv.html',
#    'suggested_link_text': 'Read the New York Times Review of Blood Brother'},
#   'multimedia': {'type': 'mediumThreeByTwo210',
#    'src': 'https://static01.nyt.com/images/2013/10/18/arts/18BLOOD_SPAN/BLOOD-mediumThreeByTwo210.jpg',
#    'width': 210,
#    'height': 140}},
#  {'display_title': 'Artists Under the Big Top: Perplexed',
#   'mpaa_rating': '',
#   'critics_pick': 0,
#   'byline': 'HOWARD THOMPSON',
#   'headline': 'Artists Under the Big Top Perplexed (Movie)',
#   'summary_short': '',
#   'publication_date': '1968-09-27',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:15:59',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1968/09/27/archives/alexander-kluge-presents-artists-under-the-big-top-perplexed.html',
#    'suggested_link_text': 'Read the New York Times Review of Artists Under the Big Top: Perplexed'},
#   'multimedia': None},
#  {'display_title': 'Before Sunset',
#   'mpaa_rating': 'R',
#   'critics_pick': 1,
#   'byline': 'A. O. Scott',
#   'headline': 'Reunited, Still Talking, Still Uneasy',
#   'summary_short': "Nine years after they parted, in Vienna, at the end of &quot;Before Sunrise,&quot;  Jesse (Ethan Hawke) and Celine (Julie Delpy) rediscover each other in Paris,  and relive their brief encounter. This time, it is even briefer: the film unfolds, without skipping a minute, in the hour or so before Jess must catch a plane home to New York, and all those minutes are filled with looping, self-conscious talk as the reunited lovers wander along the Seine.   Their intimacy is tinged with nostalgic regret. The airy sense of freedom   that they shared in their early 20's has given way to the resignation of adulthood, even as they meander toward a second chance. The liberating   sweetness of the earlier movie has mellowed into a saltier, sadder flavor, but Richard Linklater, one of our most literate and intelligent directors, has not talked himself out of the possibility of romance, and the movie's relaxed, discursive structure is dense with implied feeling and oblique drama. — A. O. Scott",
#   'publication_date': '2004-07-02',
#   'opening_date': '2004-07-30',
#   'date_updated': '2017-11-02 04:18:04',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2004/07/02/movies/film-review-reunited-still-talking-still-uneasy.html',
#    'suggested_link_text': 'Read the New York Times Review of Before Sunset'},
#   'multimedia': None},
#  {'display_title': 'It Happened One Night',
#   'mpaa_rating': 'Not Rated',
#   'critics_pick': 1,
#   'byline': 'MORDAUNT HALL.',
#   'headline': 'It Happened One Night',
#   'summary_short': 'Heiress and newspaperman on Miami bus headed north. Delicious old romantic comedy, via Capra. An Oscar mop-up.',
#   'publication_date': '1934-02-23',
#   'opening_date': '1934-02-23',
#   'date_updated': '2017-11-02 04:16:54',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1934/02/23/archives/claudette-colbert-and-clark-gable-in-a-merry-jaunt-from-miami-to.html',
#    'suggested_link_text': 'Read the New York Times Review of It Happened One Night'},
#   'multimedia': None},
#  {'display_title': 'Paris, Texas',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Vincent Canby',
#   'headline': 'PARIS, TEXAS (MOVIE)',
#   'summary_short': 'Man reunites with family, via Sam Shepard. Good portions but often elusive, static.',
#   'publication_date': '1984-10-14',
#   'opening_date': None,
#   'date_updated': '2017-11-02 04:16:08',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1984/10/14/movies/paris-texas-from-wim-wenders.html',
#    'suggested_link_text': 'Read the New York Times Review of Paris, Texas'},
#   'multimedia': None},
#  {'display_title': 'The Help',
#   'mpaa_rating': 'PG-13',
#   'critics_pick': 0,
#   'byline': 'MANOHLA DARGIS',
#   'headline': '‘The Maids’ Now Have Their Say',
#   'summary_short': '“The Help,” Tate Taylor’s movie set in civil-rights-era Mississippi, shifts between black maids and their employers.',
#   'publication_date': '2011-08-09',
#   'opening_date': '2011-08-10',
#   'date_updated': '2017-11-02 04:18:13',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/2011/08/10/movies/the-help-spans-two-worlds-white-and-black-review.html',
#    'suggested_link_text': 'Read the New York Times Review of The Help'},
#   'multimedia': None},
#  {'display_title': 'The Princess Bride',
#   'mpaa_rating': 'PG',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'Princess Bride, The (Movie)',
#   'summary_short': 'Torn between devious prince and true-love pirate. Picture-pretty fairy-tale adventure.',
#   'publication_date': '1987-09-25',
#   'opening_date': '1987-10-09',
#   'date_updated': '2017-11-02 04:17:38',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1987/09/25/movies/film-princess-bride-full-length-fairy-tale.html',
#    'suggested_link_text': 'Read the New York Times Review of The Princess Bride'},
#   'multimedia': None},
#  {'display_title': 'The Terminator',
#   'mpaa_rating': 'R',
#   'critics_pick': 0,
#   'byline': 'Janet Maslin',
#   'headline': 'TERMINATOR, THE (MOVIE)',
#   'summary_short': 'Ruthless cyborg from future. Fast, vivid sci-fi.',
#   'publication_date': '1984-10-26',
#   'opening_date': '1984-10-26',
#   'date_updated': '2017-11-02 04:17:33',
#   'link': {'type': 'article',
#    'url': 'http://www.nytimes.com/1984/10/26/movies/the-screen-terminator-suspense-tale.html',
#    'suggested_link_text': 'Read the New York Times Review of The Terminator'},
#   'multimedia': None}]

# %%
df = pd.read_json('alternate_list')
df

# %%
with open('alternate.json', 'w', encoding='UTF-8') as hey:
    json.dump(alternate_list, hey, ensure_ascii=False, indent=4)

# %%
thedf = pd.read_json('alternate.json')
thedf

# %%
from rotten_tomatoes_client import RottenTomatoesClient

meterclass = []
meterscore = []
movies_weget = []
movies_wedontget = []
for x in movie_names:
    try:
        result = RottenTomatoesClient.search(term=x, limit=1)
        if result['movies'][int(0)]['meterClass'] and result['movies'][int(0)]['meterScore']:
            meterclass.append(result['movies'][int(0)]['meterClass'])
            meterscore.append(result['movies'][int(0)]['meterScore'])
            movies_weget.append(x)
            print(x)
    except:
        movies_wedontget.append(x)
        next
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight
# 12 Angry Men
# Schindler's List
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# The Lord of the Rings: The Fellowship of the Ring
# Fight Club
# Forrest Gump
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# The Lord of the Rings: The Two Towers
# The Matrix
# Goodfellas
# One Flew Over the Cuckoo's Nest
# Shichinin no samurai
# Se7en
# La vita ? bella
# Cidade de Deus
# The Silence of the Lambs
# It's a Wonderful Life
# Star Wars
# Saving Private Ryan
# Hamilton
# The Green Mile
# Gisaengchung
# Interstellar
# L?on
# The Usual Suspects
# The Lion King
# Back to the Future
# The Pianist
# Terminator 2: Judgment Day
# American History X
# Modern Times
# Gladiator
# City Lights
# The Departed
# The Intouchables
# Whiplash
# The Prestige
# Hotaru no haka
# Once Upon a Time in the West
# Casablanca
# Nuovo Cinema Paradiso
# Rear Window
# Apocalypse Now
# Memento
# Raiders of the Lost Ark
# The Great Dictator
# Joker
# The Lives of Others
# Django Unchained
# Paths of Glory
# The Shining
# Avengers: Infinity War
# Sunset Blvd.
# Mononoke-hime
# Spider-Man: Into the Spider-Verse
# Witness for the Prosecution
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# The Dark Knight Rises
# Once Upon a Time in America
# Avengers: Endgame
# Kimi no na wa.
# Coco
# American Beauty
# Braveheart
# 3 Idiots
# Das Boot
# Toy Story
# Tengoku to jigoku
# Amadeus
# Taare Zameen Par
# Star Wars: Episode VI - Return of the Jedi
# Inglourious Basterds
# Reservoir Dogs
# Good Will Hunting
# 2001: A Space Odyssey
# Requiem for a Dream
# Vertigo
# 1917
# Dangal
# Eternal Sunshine of the Spotless Mind
# Jagten
# Citizen Kane
# Full Metal Jacket
# Ladri di biciclette
# The Kid
# A Clockwork Orange
# North by Northwest
# Snatch
# Singin' in the Rain
# Scarface
# Taxi Driver
# Am?lie
# Lawrence of Arabia
# Toy Story 3
# Ikiru
# The Sting
# Metropolis
# Jodaeiye Nader az Simin
# Incendies
# The Apartment
# Double Indemnity
# To Kill a Mockingbird
# Idi i smotri
# Indiana Jones and the Last Crusade
# Up
# L.A. Confidential
# Heat
# Monty Python and the Holy Grail
# Die Hard
# Y?jinb?
# Batman Begins
# Green Book
# Der Untergang
# Bacheha-Ye aseman
# Unforgiven
# Some Like It Hot
# Hauru no ugoku shiro
# The Great Escape
# All About Eve
# A Beautiful Mind
# Casino
# Pan's Labyrinth
# The Wolf of Wall Street
# El secreto de sus ojos
# Lock, Stock and Two Smoking Barrels
# Raging Bull
# There Will Be Blood
# Judgment at Nuremberg
# The Treasure of the Sierra Madre
# Three Billboards Outside Ebbing, Missouri
# Dial M for Murder
# The Gold Rush
# Chinatown
# V for Vendetta
# No Country for Old Men
# Shutter Island
# Det sjunde inseglet
# Inside Out
# Warrior
# The Elephant Man
# Trainspotting
# The Sixth Sense
# The Thing
# Jurassic Park
# Gone with the Wind
# Blade Runner
# Finding Nemo
# The Truman Show
# Room
# The Bridge on the River Kwai
# Stalker
# Fargo
# The Third Man
# On the Waterfront
# Gran Torino
# The Deer Hunter
# Relatos salvajes
# Andhadhun
# Klaus
# In the Name of the Father
# Mary and Max
# Gone Girl
# The Big Lebowski
# Hacksaw Ridge
# The Grand Budapest Hotel
# Before Sunrise
# To Be or Not to Be
# Catch Me If You Can
# How to Train Your Dragon
# Prisoners
# Sherlock Jr.
# Mr. Smith Goes to Washington
# 12 Years a Slave
# Barry Lyndon
# Mad Max: Fury Road
# Stand by Me
# Network
# Cool Hand Luke
# Million Dollar Baby
# Into the Wild
# Hachi: A Dog's Tale
# Ben-Hur
# Dead Poets Society
# Platoon
# Life of Brian
# Harry Potter and the Deathly Hallows: Part 2
# Logan
# Rush
# Du rififi chez les hommes
# La passion de Jeanne d'Arc
# Ah-ga-ssi
# Andrei Rublev
# Les quatre cents coups
# Hotel Rwanda
# Spotlight
# Amores perros
# Rang De Basanti
# Kaze no tani no Naushika
# Rocky
# La haine
# Gangs of Wasseypur
# Monsters, Inc.
# Rebecca
# Portrait de la jeune fille en feu
# The Circus
# Before Sunset
# It Happened One Night
# Paris, Texas
# Drishyam
# The Help
# The Princess Bride
# The Terminator
# La battaglia di Algeri

# %%
rot_df = pd.DataFrame({
    "movie_name":movies_weget,
    "meter_class" : meterclass,
    "meter_score" : meterscore
})

# %%
rot_df.set_index('movie_name', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-428cd2a95da1> in <module>
# ----> 1 rot_df.set_index('movie_name', inplace=True)
#       2 rot_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['movie_name'] are in the columns"

# %%
rot_df
# Out:
#                               meter_class  meter_score
# movie_name
# The Shawshank Redemption  certified_fresh           90
# The Godfather             certified_fresh           98
# The Godfather: Part II    certified_fresh           98
# The Dark Knight           certified_fresh           87
# 12 Angry Men              certified_fresh          100
# ...                                   ...          ...
# Drishyam                            fresh           80
# The Help                  certified_fresh           76
# The Princess Bride        certified_fresh           97
# The Terminator                     rotten           33
# La battaglia di Algeri    certified_fresh           99
#
# [219 rows x 2 columns]
